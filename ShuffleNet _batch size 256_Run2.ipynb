# %%
# The datasets library provides tools for easily accessing and working with a wide variety of datasets in various formats (text, images, audio, etc.). It's particularly useful for machine learning and natural language processing tasks.

# !pip install datasets
# Out:
# Requirement already satisfied: datasets in c:\users\jinsa\anaconda3\lib\site-packages (3.0.0)
# Requirement already satisfied: filelock in c:\users\jinsa\anaconda3\lib\site-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\jinsa\anaconda3\lib\site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\jinsa\anaconda3\lib\site-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\jinsa\anaconda3\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\jinsa\anaconda3\lib\site-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in c:\users\jinsa\anaconda3\lib\site-packages (from datasets) (2.32.2)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\jinsa\anaconda3\lib\site-packages (from datasets) (4.66.4)
# Requirement already satisfied: xxhash in c:\users\jinsa\anaconda3\lib\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess in c:\users\jinsa\anaconda3\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in c:\users\jinsa\anaconda3\lib\site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.3.1)
# Requirement already satisfied: aiohttp in c:\users\jinsa\anaconda3\lib\site-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.22.0 in c:\users\jinsa\anaconda3\lib\site-packages (from datasets) (0.25.0)
# Requirement already satisfied: packaging in c:\users\jinsa\anaconda3\lib\site-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\jinsa\anaconda3\lib\site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\jinsa\anaconda3\lib\site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\jinsa\anaconda3\lib\site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\jinsa\anaconda3\lib\site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\jinsa\anaconda3\lib\site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\jinsa\anaconda3\lib\site-packages (from aiohttp->datasets) (1.9.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\jinsa\anaconda3\lib\site-packages (from huggingface-hub>=0.22.0->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jinsa\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jinsa\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jinsa\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jinsa\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\jinsa\anaconda3\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jinsa\anaconda3\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jinsa\anaconda3\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jinsa\anaconda3\lib\site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\jinsa\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %%
# The torchvision and torchaudio packages provide essential tools for working with image and audio data in PyTorch.

# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch in c:\users\jinsa\anaconda3\lib\site-packages (2.4.1+cu118)
# Requirement already satisfied: torchvision in c:\users\jinsa\anaconda3\lib\site-packages (0.19.1)
# Requirement already satisfied: torchaudio in c:\users\jinsa\anaconda3\lib\site-packages (2.4.1+cu118)
# Requirement already satisfied: filelock in c:\users\jinsa\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\jinsa\anaconda3\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in c:\users\jinsa\anaconda3\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in c:\users\jinsa\anaconda3\lib\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\jinsa\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\jinsa\anaconda3\lib\site-packages (from torch) (2024.3.1)
# Requirement already satisfied: setuptools in c:\users\jinsa\anaconda3\lib\site-packages (from torch) (69.5.1)
# Requirement already satisfied: numpy in c:\users\jinsa\anaconda3\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\jinsa\anaconda3\lib\site-packages (from torchvision) (10.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jinsa\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\jinsa\anaconda3\lib\site-packages (from sympy->torch) (1.3.0)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models, transforms
from torch.utils.data import DataLoader
from datasets import load_dataset


ds = load_dataset("marmal88/skin_cancer")

# Use pre-split train, validation, and test sets
train_data = ds["train"]
val_data = ds["validation"]
test_data = ds["test"]

# %%
print(train_data)
# Out:
# Dataset({
#     features: ['image', 'image_id', 'lesion_id', 'dx', 'dx_type', 'age', 'sex', 'localization'],
#     num_rows: 9577
# })

# %%
# Define data transformation for preprocessing
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),  # Horizontal flip only
    transforms.RandomRotation(20),  # Rotate within ±20 degrees
    transforms.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1, hue=0.05),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
class SkinLesionDataset(torch.utils.data.Dataset):
    def __init__(self, data, transform=None):
        if not data:
            raise ValueError("Dataset cannot be empty")
        self.data = data
        self.transform = transform
        # Ensure consistent label mapping
        self.label_mapping = {
            label: idx for idx, label in enumerate(
                sorted(set(example['dx'] for example in data))
            )
        }
        
    def __len__(self):
        return len(self.data)
        
    def __getitem__(self, idx):
        if idx >= len(self.data):
            raise IndexError("Index out of range")
            
        try:
            image = self.data[idx]["image"]
            label = self.label_mapping[self.data[idx]["dx"]]
            
            if self.transform:
                image = self.transform(image)
                
            return image, label
            
        except KeyError as e:
            raise KeyError(f"Missing required key in data: {e}")
        except Exception as e:
            raise Exception(f"Error processing item {idx}: {e}")

# %%
# Create dataset objects
train_dataset = SkinLesionDataset(train_data, transform=transform)
val_dataset = SkinLesionDataset(val_data, transform=transform)
test_dataset = SkinLesionDataset(test_data, transform=transform)

# %%
# Data loaders
batch_size = 256
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# !pip install timm
# Out:
# Requirement already satisfied: timm in c:\users\jinsa\anaconda3\lib\site-packages (1.0.11)
# Requirement already satisfied: torch in c:\users\jinsa\anaconda3\lib\site-packages (from timm) (2.4.1+cu118)
# Requirement already satisfied: torchvision in c:\users\jinsa\anaconda3\lib\site-packages (from timm) (0.19.1)
# Requirement already satisfied: pyyaml in c:\users\jinsa\anaconda3\lib\site-packages (from timm) (6.0.1)
# Requirement already satisfied: huggingface_hub in c:\users\jinsa\anaconda3\lib\site-packages (from timm) (0.25.0)
# Requirement already satisfied: safetensors in c:\users\jinsa\anaconda3\lib\site-packages (from timm) (0.4.5)
# Requirement already satisfied: filelock in c:\users\jinsa\anaconda3\lib\site-packages (from huggingface_hub->timm) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\jinsa\anaconda3\lib\site-packages (from huggingface_hub->timm) (2024.3.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\jinsa\anaconda3\lib\site-packages (from huggingface_hub->timm) (23.2)
# Requirement already satisfied: requests in c:\users\jinsa\anaconda3\lib\site-packages (from huggingface_hub->timm) (2.32.2)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\jinsa\anaconda3\lib\site-packages (from huggingface_hub->timm) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\jinsa\anaconda3\lib\site-packages (from huggingface_hub->timm) (4.11.0)
# Requirement already satisfied: sympy in c:\users\jinsa\anaconda3\lib\site-packages (from torch->timm) (1.12)
# Requirement already satisfied: networkx in c:\users\jinsa\anaconda3\lib\site-packages (from torch->timm) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\jinsa\anaconda3\lib\site-packages (from torch->timm) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\jinsa\anaconda3\lib\site-packages (from torch->timm) (69.5.1)
# Requirement already satisfied: numpy in c:\users\jinsa\anaconda3\lib\site-packages (from torchvision->timm) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\jinsa\anaconda3\lib\site-packages (from torchvision->timm) (10.3.0)
# Requirement already satisfied: colorama in c:\users\jinsa\anaconda3\lib\site-packages (from tqdm>=4.42.1->huggingface_hub->timm) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jinsa\anaconda3\lib\site-packages (from jinja2->torch->timm) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jinsa\anaconda3\lib\site-packages (from requests->huggingface_hub->timm) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jinsa\anaconda3\lib\site-packages (from requests->huggingface_hub->timm) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jinsa\anaconda3\lib\site-packages (from requests->huggingface_hub->timm) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jinsa\anaconda3\lib\site-packages (from requests->huggingface_hub->timm) (2024.8.30)
# Requirement already satisfied: mpmath>=0.19 in c:\users\jinsa\anaconda3\lib\site-packages (from sympy->torch->timm) (1.3.0)

# %%
import timm
timm.list_models()
# Out:
# ['bat_resnext26ts',
#  'beit_base_patch16_224',
#  'beit_base_patch16_384',
#  'beit_large_patch16_224',
#  'beit_large_patch16_384',
#  'beit_large_patch16_512',
#  'beitv2_base_patch16_224',
#  'beitv2_large_patch16_224',
#  'botnet26t_256',
#  'botnet50ts_256',
#  'caformer_b36',
#  'caformer_m36',
#  'caformer_s18',
#  'caformer_s36',
#  'cait_m36_384',
#  'cait_m48_448',
#  'cait_s24_224',
#  'cait_s24_384',
#  'cait_s36_384',
#  'cait_xs24_384',
#  'cait_xxs24_224',
#  'cait_xxs24_384',
#  'cait_xxs36_224',
#  'cait_xxs36_384',
#  'coat_lite_medium',
#  'coat_lite_medium_384',
#  'coat_lite_mini',
#  'coat_lite_small',
#  'coat_lite_tiny',
#  'coat_mini',
#  'coat_small',
#  'coat_tiny',
#  'coatnet_0_224',
#  'coatnet_0_rw_224',
#  'coatnet_1_224',
#  'coatnet_1_rw_224',
#  'coatnet_2_224',
#  'coatnet_2_rw_224',
#  'coatnet_3_224',
#  'coatnet_3_rw_224',
#  'coatnet_4_224',
#  'coatnet_5_224',
#  'coatnet_bn_0_rw_224',
#  'coatnet_nano_cc_224',
#  'coatnet_nano_rw_224',
#  'coatnet_pico_rw_224',
#  'coatnet_rmlp_0_rw_224',
#  'coatnet_rmlp_1_rw2_224',
#  'coatnet_rmlp_1_rw_224',
#  'coatnet_rmlp_2_rw_224',
#  'coatnet_rmlp_2_rw_384',
#  'coatnet_rmlp_3_rw_224',
#  'coatnet_rmlp_nano_rw_224',
#  'coatnext_nano_rw_224',
#  'convformer_b36',
#  'convformer_m36',
#  'convformer_s18',
#  'convformer_s36',
#  'convit_base',
#  'convit_small',
#  'convit_tiny',
#  'convmixer_768_32',
#  'convmixer_1024_20_ks9_p14',
#  'convmixer_1536_20',
#  'convnext_atto',
#  'convnext_atto_ols',
#  'convnext_atto_rms',
#  'convnext_base',
#  'convnext_femto',
#  'convnext_femto_ols',
#  'convnext_large',
#  'convnext_large_mlp',
#  'convnext_nano',
#  'convnext_nano_ols',
#  'convnext_pico',
#  'convnext_pico_ols',
#  'convnext_small',
#  'convnext_tiny',
#  'convnext_tiny_hnf',
#  'convnext_xlarge',
#  'convnext_xxlarge',
#  'convnext_zepto_rms',
#  'convnext_zepto_rms_ols',
#  'convnextv2_atto',
#  'convnextv2_base',
#  'convnextv2_femto',
#  'convnextv2_huge',
#  'convnextv2_large',
#  'convnextv2_nano',
#  'convnextv2_pico',
#  'convnextv2_small',
#  'convnextv2_tiny',
#  'crossvit_9_240',
#  'crossvit_9_dagger_240',
#  'crossvit_15_240',
#  'crossvit_15_dagger_240',
#  'crossvit_15_dagger_408',
#  'crossvit_18_240',
#  'crossvit_18_dagger_240',
#  'crossvit_18_dagger_408',
#  'crossvit_base_240',
#  'crossvit_small_240',
#  'crossvit_tiny_240',
#  'cs3darknet_focus_l',
#  'cs3darknet_focus_m',
#  'cs3darknet_focus_s',
#  'cs3darknet_focus_x',
#  'cs3darknet_l',
#  'cs3darknet_m',
#  'cs3darknet_s',
#  'cs3darknet_x',
#  'cs3edgenet_x',
#  'cs3se_edgenet_x',
#  'cs3sedarknet_l',
#  'cs3sedarknet_x',
#  'cs3sedarknet_xdw',
#  'cspdarknet53',
#  'cspresnet50',
#  'cspresnet50d',
#  'cspresnet50w',
#  'cspresnext50',
#  'darknet17',
#  'darknet21',
#  'darknet53',
#  'darknetaa53',
#  'davit_base',
#  'davit_base_fl',
#  'davit_giant',
#  'davit_huge',
#  'davit_huge_fl',
#  'davit_large',
#  'davit_small',
#  'davit_tiny',
#  'deit3_base_patch16_224',
#  'deit3_base_patch16_384',
#  'deit3_huge_patch14_224',
#  'deit3_large_patch16_224',
#  'deit3_large_patch16_384',
#  'deit3_medium_patch16_224',
#  'deit3_small_patch16_224',
#  'deit3_small_patch16_384',
#  'deit_base_distilled_patch16_224',
#  'deit_base_distilled_patch16_384',
#  'deit_base_patch16_224',
#  'deit_base_patch16_384',
#  'deit_small_distilled_patch16_224',
#  'deit_small_patch16_224',
#  'deit_tiny_distilled_patch16_224',
#  'deit_tiny_patch16_224',
#  'densenet121',
#  'densenet161',
#  'densenet169',
#  'densenet201',
#  'densenet264d',
#  'densenetblur121d',
#  'dla34',
#  'dla46_c',
#  'dla46x_c',
#  'dla60',
#  'dla60_res2net',
#  'dla60_res2next',
#  'dla60x',
#  'dla60x_c',
#  'dla102',
#  'dla102x',
#  'dla102x2',
#  'dla169',
#  'dm_nfnet_f0',
#  'dm_nfnet_f1',
#  'dm_nfnet_f2',
#  'dm_nfnet_f3',
#  'dm_nfnet_f4',
#  'dm_nfnet_f5',
#  'dm_nfnet_f6',
#  'dpn48b',
#  'dpn68',
#  'dpn68b',
#  'dpn92',
#  'dpn98',
#  'dpn107',
#  'dpn131',
#  'eca_botnext26ts_256',
#  'eca_halonext26ts',
#  'eca_nfnet_l0',
#  'eca_nfnet_l1',
#  'eca_nfnet_l2',
#  'eca_nfnet_l3',
#  'eca_resnet33ts',
#  'eca_resnext26ts',
#  'eca_vovnet39b',
#  'ecaresnet26t',
#  'ecaresnet50d',
#  'ecaresnet50d_pruned',
#  'ecaresnet50t',
#  'ecaresnet101d',
#  'ecaresnet101d_pruned',
#  'ecaresnet200d',
#  'ecaresnet269d',
#  'ecaresnetlight',
#  'ecaresnext26t_32x4d',
#  'ecaresnext50t_32x4d',
#  'edgenext_base',
#  'edgenext_small',
#  'edgenext_small_rw',
#  'edgenext_x_small',
#  'edgenext_xx_small',
#  'efficientformer_l1',
#  'efficientformer_l3',
#  'efficientformer_l7',
#  'efficientformerv2_l',
#  'efficientformerv2_s0',
#  'efficientformerv2_s1',
#  'efficientformerv2_s2',
#  'efficientnet_b0',
#  'efficientnet_b0_g8_gn',
#  'efficientnet_b0_g16_evos',
#  'efficientnet_b0_gn',
#  'efficientnet_b1',
#  'efficientnet_b1_pruned',
#  'efficientnet_b2',
#  'efficientnet_b2_pruned',
#  'efficientnet_b3',
#  'efficientnet_b3_g8_gn',
#  'efficientnet_b3_gn',
#  'efficientnet_b3_pruned',
#  'efficientnet_b4',
#  'efficientnet_b5',
#  'efficientnet_b6',
#  'efficientnet_b7',
#  'efficientnet_b8',
#  'efficientnet_blur_b0',
#  'efficientnet_cc_b0_4e',
#  'efficientnet_cc_b0_8e',
#  'efficientnet_cc_b1_8e',
#  'efficientnet_el',
#  'efficientnet_el_pruned',
#  'efficientnet_em',
#  'efficientnet_es',
#  'efficientnet_es_pruned',
#  'efficientnet_h_b5',
#  'efficientnet_l2',
#  'efficientnet_lite0',
#  'efficientnet_lite1',
#  'efficientnet_lite2',
#  'efficientnet_lite3',
#  'efficientnet_lite4',
#  'efficientnet_x_b3',
#  'efficientnet_x_b5',
#  'efficientnetv2_l',
#  'efficientnetv2_m',
#  'efficientnetv2_rw_m',
#  'efficientnetv2_rw_s',
#  'efficientnetv2_rw_t',
#  'efficientnetv2_s',
#  'efficientnetv2_xl',
#  'efficientvit_b0',
#  'efficientvit_b1',
#  'efficientvit_b2',
#  'efficientvit_b3',
#  'efficientvit_l1',
#  'efficientvit_l2',
#  'efficientvit_l3',
#  'efficientvit_m0',
#  'efficientvit_m1',
#  'efficientvit_m2',
#  'efficientvit_m3',
#  'efficientvit_m4',
#  'efficientvit_m5',
#  'ese_vovnet19b_dw',
#  'ese_vovnet19b_slim',
#  'ese_vovnet19b_slim_dw',
#  'ese_vovnet39b',
#  'ese_vovnet39b_evos',
#  'ese_vovnet57b',
#  'ese_vovnet99b',
#  'eva02_base_patch14_224',
#  'eva02_base_patch14_448',
#  'eva02_base_patch16_clip_224',
#  'eva02_enormous_patch14_clip_224',
#  'eva02_large_patch14_224',
#  'eva02_large_patch14_448',
#  'eva02_large_patch14_clip_224',
#  'eva02_large_patch14_clip_336',
#  'eva02_small_patch14_224',
#  'eva02_small_patch14_336',
#  'eva02_tiny_patch14_224',
#  'eva02_tiny_patch14_336',
#  'eva_giant_patch14_224',
#  'eva_giant_patch14_336',
#  'eva_giant_patch14_560',
#  'eva_giant_patch14_clip_224',
#  'eva_large_patch14_196',
#  'eva_large_patch14_336',
#  'fastvit_ma36',
#  'fastvit_mci0',
#  'fastvit_mci1',
#  'fastvit_mci2',
#  'fastvit_s12',
#  'fastvit_sa12',
#  'fastvit_sa24',
#  'fastvit_sa36',
#  'fastvit_t8',
#  'fastvit_t12',
#  'fbnetc_100',
#  'fbnetv3_b',
#  'fbnetv3_d',
#  'fbnetv3_g',
#  'flexivit_base',
#  'flexivit_large',
#  'flexivit_small',
#  'focalnet_base_lrf',
#  'focalnet_base_srf',
#  'focalnet_huge_fl3',
#  'focalnet_huge_fl4',
#  'focalnet_large_fl3',
#  'focalnet_large_fl4',
#  'focalnet_small_lrf',
#  'focalnet_small_srf',
#  'focalnet_tiny_lrf',
#  'focalnet_tiny_srf',
#  'focalnet_xlarge_fl3',
#  'focalnet_xlarge_fl4',
#  'gc_efficientnetv2_rw_t',
#  'gcresnet33ts',
#  'gcresnet50t',
#  'gcresnext26ts',
#  'gcresnext50ts',
#  'gcvit_base',
#  'gcvit_small',
#  'gcvit_tiny',
#  'gcvit_xtiny',
#  'gcvit_xxtiny',
#  'gernet_l',
#  'gernet_m',
#  'gernet_s',
#  'ghostnet_050',
#  'ghostnet_100',
#  'ghostnet_130',
#  'ghostnetv2_100',
#  'ghostnetv2_130',
#  'ghostnetv2_160',
#  'gmixer_12_224',
#  'gmixer_24_224',
#  'gmlp_b16_224',
#  'gmlp_s16_224',
#  'gmlp_ti16_224',
#  'halo2botnet50ts_256',
#  'halonet26t',
#  'halonet50ts',
#  'halonet_h1',
#  'haloregnetz_b',
#  'hardcorenas_a',
#  'hardcorenas_b',
#  'hardcorenas_c',
#  'hardcorenas_d',
#  'hardcorenas_e',
#  'hardcorenas_f',
#  'hgnet_base',
#  'hgnet_small',
#  'hgnet_tiny',
#  'hgnetv2_b0',
#  'hgnetv2_b1',
#  'hgnetv2_b2',
#  'hgnetv2_b3',
#  'hgnetv2_b4',
#  'hgnetv2_b5',
#  'hgnetv2_b6',
#  'hiera_base_224',
#  'hiera_base_abswin_256',
#  'hiera_base_plus_224',
#  'hiera_huge_224',
#  'hiera_large_224',
#  'hiera_small_224',
#  'hiera_small_abswin_256',
#  'hiera_tiny_224',
#  'hieradet_small',
#  'hrnet_w18',
#  'hrnet_w18_small',
#  'hrnet_w18_small_v2',
#  'hrnet_w18_ssld',
#  'hrnet_w30',
#  'hrnet_w32',
#  'hrnet_w40',
#  'hrnet_w44',
#  'hrnet_w48',
#  'hrnet_w48_ssld',
#  'hrnet_w64',
#  'inception_next_base',
#  'inception_next_small',
#  'inception_next_tiny',
#  'inception_resnet_v2',
#  'inception_v3',
#  'inception_v4',
#  'lambda_resnet26rpt_256',
#  'lambda_resnet26t',
#  'lambda_resnet50ts',
#  'lamhalobotnet50ts_256',
#  'lcnet_035',
#  'lcnet_050',
#  'lcnet_075',
#  'lcnet_100',
#  'lcnet_150',
#  'legacy_senet154',
#  'legacy_seresnet18',
#  'legacy_seresnet34',
#  'legacy_seresnet50',
#  'legacy_seresnet101',
#  'legacy_seresnet152',
#  'legacy_seresnext26_32x4d',
#  'legacy_seresnext50_32x4d',
#  'legacy_seresnext101_32x4d',
#  'legacy_xception',
#  'levit_128',
#  'levit_128s',
#  'levit_192',
#  'levit_256',
#  'levit_256d',
#  'levit_384',
#  'levit_384_s8',
#  'levit_512',
#  'levit_512_s8',
#  'levit_512d',
#  'levit_conv_128',
#  'levit_conv_128s',
#  'levit_conv_192',
#  'levit_conv_256',
#  'levit_conv_256d',
#  'levit_conv_384',
#  'levit_conv_384_s8',
#  'levit_conv_512',
#  'levit_conv_512_s8',
#  'levit_conv_512d',
#  'mambaout_base',
#  'mambaout_base_plus_rw',
#  'mambaout_base_short_rw',
#  'mambaout_base_tall_rw',
#  'mambaout_base_wide_rw',
#  'mambaout_femto',
#  'mambaout_kobe',
#  'mambaout_small',
#  'mambaout_small_rw',
#  'mambaout_tiny',
#  'maxvit_base_tf_224',
#  'maxvit_base_tf_384',
#  'maxvit_base_tf_512',
#  'maxvit_large_tf_224',
#  'maxvit_large_tf_384',
#  'maxvit_large_tf_512',
#  'maxvit_nano_rw_256',
#  'maxvit_pico_rw_256',
#  'maxvit_rmlp_base_rw_224',
#  'maxvit_rmlp_base_rw_384',
#  'maxvit_rmlp_nano_rw_256',
#  'maxvit_rmlp_pico_rw_256',
#  'maxvit_rmlp_small_rw_224',
#  'maxvit_rmlp_small_rw_256',
#  'maxvit_rmlp_tiny_rw_256',
#  'maxvit_small_tf_224',
#  'maxvit_small_tf_384',
#  'maxvit_small_tf_512',
#  'maxvit_tiny_pm_256',
#  'maxvit_tiny_rw_224',
#  'maxvit_tiny_rw_256',
#  'maxvit_tiny_tf_224',
#  'maxvit_tiny_tf_384',
#  'maxvit_tiny_tf_512',
#  'maxvit_xlarge_tf_224',
#  'maxvit_xlarge_tf_384',
#  'maxvit_xlarge_tf_512',
#  'maxxvit_rmlp_nano_rw_256',
#  'maxxvit_rmlp_small_rw_256',
#  'maxxvit_rmlp_tiny_rw_256',
#  'maxxvitv2_nano_rw_256',
#  'maxxvitv2_rmlp_base_rw_224',
#  'maxxvitv2_rmlp_base_rw_384',
#  'maxxvitv2_rmlp_large_rw_224',
#  'mixer_b16_224',
#  'mixer_b32_224',
#  'mixer_l16_224',
#  'mixer_l32_224',
#  'mixer_s16_224',
#  'mixer_s32_224',
#  'mixnet_l',
#  'mixnet_m',
#  'mixnet_s',
#  'mixnet_xl',
#  'mixnet_xxl',
#  'mnasnet_050',
#  'mnasnet_075',
#  'mnasnet_100',
#  'mnasnet_140',
#  'mnasnet_small',
#  'mobilenet_edgetpu_100',
#  'mobilenet_edgetpu_v2_l',
#  'mobilenet_edgetpu_v2_m',
#  'mobilenet_edgetpu_v2_s',
#  'mobilenet_edgetpu_v2_xs',
#  'mobilenetv1_100',
#  'mobilenetv1_100h',
#  'mobilenetv1_125',
#  'mobilenetv2_035',
#  'mobilenetv2_050',
#  'mobilenetv2_075',
#  'mobilenetv2_100',
#  'mobilenetv2_110d',
#  'mobilenetv2_120d',
#  'mobilenetv2_140',
#  'mobilenetv3_large_075',
#  'mobilenetv3_large_100',
#  'mobilenetv3_large_150d',
#  'mobilenetv3_rw',
#  'mobilenetv3_small_050',
#  'mobilenetv3_small_075',
#  'mobilenetv3_small_100',
#  'mobilenetv4_conv_aa_large',
#  'mobilenetv4_conv_aa_medium',
#  'mobilenetv4_conv_blur_medium',
#  'mobilenetv4_conv_large',
#  'mobilenetv4_conv_medium',
#  'mobilenetv4_conv_small',
#  'mobilenetv4_conv_small_035',
#  'mobilenetv4_conv_small_050',
#  'mobilenetv4_hybrid_large',
#  'mobilenetv4_hybrid_large_075',
#  'mobilenetv4_hybrid_medium',
#  'mobilenetv4_hybrid_medium_075',
#  'mobileone_s0',
#  'mobileone_s1',
#  'mobileone_s2',
#  'mobileone_s3',
#  'mobileone_s4',
#  'mobilevit_s',
#  'mobilevit_xs',
#  'mobilevit_xxs',
#  'mobilevitv2_050',
#  'mobilevitv2_075',
#  'mobilevitv2_100',
#  'mobilevitv2_125',
#  'mobilevitv2_150',
#  'mobilevitv2_175',
#  'mobilevitv2_200',
#  'mvitv2_base',
#  'mvitv2_base_cls',
#  'mvitv2_huge_cls',
#  'mvitv2_large',
#  'mvitv2_large_cls',
#  'mvitv2_small',
#  'mvitv2_small_cls',
#  'mvitv2_tiny',
#  'nasnetalarge',
#  'nest_base',
#  'nest_base_jx',
#  'nest_small',
#  'nest_small_jx',
#  'nest_tiny',
#  'nest_tiny_jx',
#  'nextvit_base',
#  'nextvit_large',
#  'nextvit_small',
#  'nf_ecaresnet26',
#  'nf_ecaresnet50',
#  'nf_ecaresnet101',
#  'nf_regnet_b0',
#  'nf_regnet_b1',
#  'nf_regnet_b2',
#  'nf_regnet_b3',
#  'nf_regnet_b4',
#  'nf_regnet_b5',
#  'nf_resnet26',
#  'nf_resnet50',
#  'nf_resnet101',
#  'nf_seresnet26',
#  'nf_seresnet50',
#  'nf_seresnet101',
#  'nfnet_f0',
#  'nfnet_f1',
#  'nfnet_f2',
#  'nfnet_f3',
#  'nfnet_f4',
#  'nfnet_f5',
#  'nfnet_f6',
#  'nfnet_f7',
#  'nfnet_l0',
#  'pit_b_224',
#  'pit_b_distilled_224',
#  'pit_s_224',
#  'pit_s_distilled_224',
#  'pit_ti_224',
#  'pit_ti_distilled_224',
#  'pit_xs_224',
#  'pit_xs_distilled_224',
#  'pnasnet5large',
#  'poolformer_m36',
#  'poolformer_m48',
#  'poolformer_s12',
#  'poolformer_s24',
#  'poolformer_s36',
#  'poolformerv2_m36',
#  'poolformerv2_m48',
#  'poolformerv2_s12',
#  'poolformerv2_s24',
#  'poolformerv2_s36',
#  'pvt_v2_b0',
#  'pvt_v2_b1',
#  'pvt_v2_b2',
#  'pvt_v2_b2_li',
#  'pvt_v2_b3',
#  'pvt_v2_b4',
#  'pvt_v2_b5',
#  'rdnet_base',
#  'rdnet_large',
#  'rdnet_small',
#  'rdnet_tiny',
#  'regnetv_040',
#  'regnetv_064',
#  'regnetx_002',
#  'regnetx_004',
#  'regnetx_004_tv',
#  'regnetx_006',
#  'regnetx_008',
#  'regnetx_016',
#  'regnetx_032',
#  'regnetx_040',
#  'regnetx_064',
#  'regnetx_080',
#  'regnetx_120',
#  'regnetx_160',
#  'regnetx_320',
#  'regnety_002',
#  'regnety_004',
#  'regnety_006',
#  'regnety_008',
#  'regnety_008_tv',
#  'regnety_016',
#  'regnety_032',
#  'regnety_040',
#  'regnety_040_sgn',
#  'regnety_064',
#  'regnety_080',
#  'regnety_080_tv',
#  'regnety_120',
#  'regnety_160',
#  'regnety_320',
#  'regnety_640',
#  'regnety_1280',
#  'regnety_2560',
#  'regnetz_005',
#  'regnetz_040',
#  'regnetz_040_h',
#  'regnetz_b16',
#  'regnetz_b16_evos',
#  'regnetz_c16',
#  'regnetz_c16_evos',
#  'regnetz_d8',
#  'regnetz_d8_evos',
#  'regnetz_d32',
#  'regnetz_e8',
#  'repghostnet_050',
#  'repghostnet_058',
#  'repghostnet_080',
#  'repghostnet_100',
#  'repghostnet_111',
#  'repghostnet_130',
#  'repghostnet_150',
#  'repghostnet_200',
#  'repvgg_a0',
#  'repvgg_a1',
#  'repvgg_a2',
#  'repvgg_b0',
#  'repvgg_b1',
#  'repvgg_b1g4',
#  'repvgg_b2',
#  'repvgg_b2g4',
#  'repvgg_b3',
#  'repvgg_b3g4',
#  'repvgg_d2se',
#  'repvit_m0_9',
#  'repvit_m1',
#  'repvit_m1_0',
#  'repvit_m1_1',
#  'repvit_m1_5',
#  'repvit_m2',
#  'repvit_m2_3',
#  'repvit_m3',
#  'res2net50_14w_8s',
#  'res2net50_26w_4s',
#  'res2net50_26w_6s',
#  'res2net50_26w_8s',
#  'res2net50_48w_2s',
#  'res2net50d',
#  'res2net101_26w_4s',
#  'res2net101d',
#  'res2next50',
#  'resmlp_12_224',
#  'resmlp_24_224',
#  'resmlp_36_224',
#  'resmlp_big_24_224',
#  'resnest14d',
#  'resnest26d',
#  'resnest50d',
#  'resnest50d_1s4x24d',
#  'resnest50d_4s2x40d',
#  'resnest101e',
#  'resnest200e',
#  'resnest269e',
#  'resnet10t',
#  'resnet14t',
#  'resnet18',
#  'resnet18d',
#  'resnet26',
#  'resnet26d',
#  'resnet26t',
#  'resnet32ts',
#  'resnet33ts',
#  'resnet34',
#  'resnet34d',
#  'resnet50',
#  'resnet50_clip',
#  'resnet50_clip_gap',
#  'resnet50_gn',
#  'resnet50_mlp',
#  'resnet50c',
#  'resnet50d',
#  'resnet50s',
#  'resnet50t',
#  'resnet50x4_clip',
#  'resnet50x4_clip_gap',
#  'resnet50x16_clip',
#  'resnet50x16_clip_gap',
#  'resnet50x64_clip',
#  'resnet50x64_clip_gap',
#  'resnet51q',
#  'resnet61q',
#  'resnet101',
#  'resnet101_clip',
#  'resnet101_clip_gap',
#  'resnet101c',
#  'resnet101d',
#  'resnet101s',
#  'resnet152',
#  'resnet152c',
#  'resnet152d',
#  'resnet152s',
#  'resnet200',
#  'resnet200d',
#  'resnetaa34d',
#  'resnetaa50',
#  'resnetaa50d',
#  'resnetaa101d',
#  'resnetblur18',
#  'resnetblur50',
#  'resnetblur50d',
#  'resnetblur101d',
#  'resnetrs50',
#  'resnetrs101',
#  'resnetrs152',
#  'resnetrs200',
#  'resnetrs270',
#  'resnetrs350',
#  'resnetrs420',
#  'resnetv2_18',
#  'resnetv2_18d',
#  'resnetv2_34',
#  'resnetv2_34d',
#  'resnetv2_50',
#  'resnetv2_50d',
#  'resnetv2_50d_evos',
#  'resnetv2_50d_frn',
#  'resnetv2_50d_gn',
#  'resnetv2_50t',
#  'resnetv2_50x1_bit',
#  'resnetv2_50x3_bit',
#  'resnetv2_101',
#  'resnetv2_101d',
#  'resnetv2_101x1_bit',
#  'resnetv2_101x3_bit',
#  'resnetv2_152',
#  'resnetv2_152d',
#  'resnetv2_152x2_bit',
#  'resnetv2_152x4_bit',
#  'resnext26ts',
#  'resnext50_32x4d',
#  'resnext50d_32x4d',
#  'resnext101_32x4d',
#  'resnext101_32x8d',
#  'resnext101_32x16d',
#  'resnext101_32x32d',
#  'resnext101_64x4d',
#  'rexnet_100',
#  'rexnet_130',
#  'rexnet_150',
#  'rexnet_200',
#  'rexnet_300',
#  'rexnetr_100',
#  'rexnetr_130',
#  'rexnetr_150',
#  'rexnetr_200',
#  'rexnetr_300',
#  'sam2_hiera_base_plus',
#  'sam2_hiera_large',
#  'sam2_hiera_small',
#  'sam2_hiera_tiny',
#  'samvit_base_patch16',
#  'samvit_base_patch16_224',
#  'samvit_huge_patch16',
#  'samvit_large_patch16',
#  'sebotnet33ts_256',
#  'sedarknet21',
#  'sehalonet33ts',
#  'selecsls42',
#  'selecsls42b',
#  'selecsls60',
#  'selecsls60b',
#  'selecsls84',
#  'semnasnet_050',
#  'semnasnet_075',
#  'semnasnet_100',
#  'semnasnet_140',
#  'senet154',
#  'sequencer2d_l',
#  'sequencer2d_m',
#  'sequencer2d_s',
#  'seresnet18',
#  'seresnet33ts',
#  'seresnet34',
#  'seresnet50',
#  'seresnet50t',
#  'seresnet101',
#  'seresnet152',
#  'seresnet152d',
#  'seresnet200d',
#  'seresnet269d',
#  'seresnetaa50d',
#  'seresnext26d_32x4d',
#  'seresnext26t_32x4d',
#  'seresnext26ts',
#  'seresnext50_32x4d',
#  'seresnext101_32x4d',
#  'seresnext101_32x8d',
#  'seresnext101_64x4d',
#  'seresnext101d_32x8d',
#  'seresnextaa101d_32x8d',
#  'seresnextaa201d_32x8d',
#  'skresnet18',
#  'skresnet34',
#  'skresnet50',
#  'skresnet50d',
#  'skresnext50_32x4d',
#  'spnasnet_100',
#  'swin_base_patch4_window7_224',
#  'swin_base_patch4_window12_384',
#  'swin_large_patch4_window7_224',
#  'swin_large_patch4_window12_384',
#  'swin_s3_base_224',
#  'swin_s3_small_224',
#  'swin_s3_tiny_224',
#  'swin_small_patch4_window7_224',
#  'swin_tiny_patch4_window7_224',
#  'swinv2_base_window8_256',
#  'swinv2_base_window12_192',
#  'swinv2_base_window12to16_192to256',
#  'swinv2_base_window12to24_192to384',
#  'swinv2_base_window16_256',
#  'swinv2_cr_base_224',
#  'swinv2_cr_base_384',
#  'swinv2_cr_base_ns_224',
#  'swinv2_cr_giant_224',
#  'swinv2_cr_giant_384',
#  'swinv2_cr_huge_224',
#  'swinv2_cr_huge_384',
#  'swinv2_cr_large_224',
#  'swinv2_cr_large_384',
#  'swinv2_cr_small_224',
#  'swinv2_cr_small_384',
#  'swinv2_cr_small_ns_224',
#  'swinv2_cr_small_ns_256',
#  'swinv2_cr_tiny_224',
#  'swinv2_cr_tiny_384',
#  'swinv2_cr_tiny_ns_224',
#  'swinv2_large_window12_192',
#  'swinv2_large_window12to16_192to256',
#  'swinv2_large_window12to24_192to384',
#  'swinv2_small_window8_256',
#  'swinv2_small_window16_256',
#  'swinv2_tiny_window8_256',
#  'swinv2_tiny_window16_256',
#  'test_byobnet',
#  'test_convnext',
#  'test_convnext2',
#  'test_convnext3',
#  'test_efficientnet',
#  'test_efficientnet_evos',
#  'test_efficientnet_gn',
#  'test_efficientnet_ln',
#  'test_mambaout',
#  'test_nfnet',
#  'test_resnet',
#  'test_vit',
#  'test_vit2',
#  'test_vit3',
#  'tf_efficientnet_b0',
#  'tf_efficientnet_b1',
#  'tf_efficientnet_b2',
#  'tf_efficientnet_b3',
#  'tf_efficientnet_b4',
#  'tf_efficientnet_b5',
#  'tf_efficientnet_b6',
#  'tf_efficientnet_b7',
#  'tf_efficientnet_b8',
#  'tf_efficientnet_cc_b0_4e',
#  'tf_efficientnet_cc_b0_8e',
#  'tf_efficientnet_cc_b1_8e',
#  'tf_efficientnet_el',
#  'tf_efficientnet_em',
#  'tf_efficientnet_es',
#  'tf_efficientnet_l2',
#  'tf_efficientnet_lite0',
#  'tf_efficientnet_lite1',
#  'tf_efficientnet_lite2',
#  'tf_efficientnet_lite3',
#  'tf_efficientnet_lite4',
#  'tf_efficientnetv2_b0',
#  'tf_efficientnetv2_b1',
#  'tf_efficientnetv2_b2',
#  'tf_efficientnetv2_b3',
#  'tf_efficientnetv2_l',
#  'tf_efficientnetv2_m',
#  'tf_efficientnetv2_s',
#  'tf_efficientnetv2_xl',
#  'tf_mixnet_l',
#  'tf_mixnet_m',
#  'tf_mixnet_s',
#  'tf_mobilenetv3_large_075',
#  'tf_mobilenetv3_large_100',
#  'tf_mobilenetv3_large_minimal_100',
#  'tf_mobilenetv3_small_075',
#  'tf_mobilenetv3_small_100',
#  'tf_mobilenetv3_small_minimal_100',
#  'tiny_vit_5m_224',
#  'tiny_vit_11m_224',
#  'tiny_vit_21m_224',
#  'tiny_vit_21m_384',
#  'tiny_vit_21m_512',
#  'tinynet_a',
#  'tinynet_b',
#  'tinynet_c',
#  'tinynet_d',
#  'tinynet_e',
#  'tnt_b_patch16_224',
#  'tnt_s_patch16_224',
#  'tresnet_l',
#  'tresnet_m',
#  'tresnet_v2_l',
#  'tresnet_xl',
#  'twins_pcpvt_base',
#  'twins_pcpvt_large',
#  'twins_pcpvt_small',
#  'twins_svt_base',
#  'twins_svt_large',
#  'twins_svt_small',
#  'vgg11',
#  'vgg11_bn',
#  'vgg13',
#  'vgg13_bn',
#  'vgg16',
#  'vgg16_bn',
#  'vgg19',
#  'vgg19_bn',
#  'visformer_small',
#  'visformer_tiny',
#  'vit_base_mci_224',
#  'vit_base_patch8_224',
#  'vit_base_patch14_dinov2',
#  'vit_base_patch14_reg4_dinov2',
#  'vit_base_patch16_18x2_224',
#  'vit_base_patch16_224',
#  'vit_base_patch16_224_miil',
#  'vit_base_patch16_384',
#  'vit_base_patch16_clip_224',
#  'vit_base_patch16_clip_384',
#  'vit_base_patch16_clip_quickgelu_224',
#  'vit_base_patch16_gap_224',
#  'vit_base_patch16_plus_240',
#  'vit_base_patch16_reg4_gap_256',
#  'vit_base_patch16_rope_reg1_gap_256',
#  'vit_base_patch16_rpn_224',
#  'vit_base_patch16_siglip_224',
#  'vit_base_patch16_siglip_256',
#  'vit_base_patch16_siglip_384',
#  'vit_base_patch16_siglip_512',
#  'vit_base_patch16_siglip_gap_224',
#  'vit_base_patch16_siglip_gap_256',
#  'vit_base_patch16_siglip_gap_384',
#  'vit_base_patch16_siglip_gap_512',
#  'vit_base_patch16_xp_224',
#  'vit_base_patch32_224',
#  'vit_base_patch32_384',
#  'vit_base_patch32_clip_224',
#  'vit_base_patch32_clip_256',
#  'vit_base_patch32_clip_384',
#  ...]

# %%
from torchvision.models import shufflenet_v2_x1_0

# Load a pre-trained ShuffleNet v2 model with 1.0x output channels
model = shufflenet_v2_x1_0(pretrained=True)

# Modify the final layer to match the number of classes in your dataset
num_classes = len(set(train_data['dx']))  # Replace 'train_data' with your data reference
model.fc = torch.nn.Linear(model.fc.in_features, num_classes)
# Out:
# C:\Users\JinSa\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\JinSa\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ShuffleNet_V2_X1_0_Weights.IMAGENET1K_V1`. You can also use `weights=ShuffleNet_V2_X1_0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# Set device to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %%
print(next(model.parameters()).device)
# Out:
# cuda:0

# %%
# Loss function and optimizer
from torch.optim.lr_scheduler import OneCycleLR  # Import OneCycleLR
train_labels_numeric = [train_dataset.label_mapping[label] for label in train_data['dx']]
class_counts = torch.bincount(torch.tensor(train_labels_numeric))
class_weights = (1.0 / class_counts.float())  
class_weights = class_weights / class_weights.sum()  # Normalize weights

# Loss function with class weights
criterion = nn.CrossEntropyLoss(weight=class_weights.to(device))

# AdamW optimizer with weight decay
optimizer = optim.AdamW(
    filter(lambda p: p.requires_grad, model.parameters()), 
    lr=1e-3, weight_decay=1e-4
)

num_epochs = 75
total_steps = num_epochs * len(train_loader)  # Calculate total steps correctly


# One-Cycle Learning Rate scheduler
scheduler = OneCycleLR(
    optimizer,
    max_lr=1e-3,
    total_steps=total_steps,  # Use total_steps instead of steps_per_epoch
    pct_start=0.3,
    anneal_strategy='cos',
    cycle_momentum=False,
)

# %%
pip install datetime
# Out:
# Requirement already satisfied: datetime in c:\users\jinsa\anaconda3\lib\site-packages (5.5)
# Requirement already satisfied: zope.interface in c:\users\jinsa\anaconda3\lib\site-packages (from datetime) (5.4.0)
# Requirement already satisfied: pytz in c:\users\jinsa\anaconda3\lib\site-packages (from datetime) (2024.1)
# Requirement already satisfied: setuptools in c:\users\jinsa\anaconda3\lib\site-packages (from zope.interface->datetime) (69.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from datetime import datetime

# Training loop with validation accuracy monitoring and training loss display

best_val_acc = 0

for epoch in range(num_epochs):
    model.train()  # Set model to training mode
    running_loss = 0.0
    correct_train = 0
    total_train = 0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        
        # Apply gradient clipping to prevent exploding gradients
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        
        optimizer.step()
        scheduler.step()  # Adjust learning rate
        
        running_loss += loss.item()
        
        _, predicted = torch.max(outputs.data, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()
        
    # Calculate average loss and accuracy for the epoch   
    avg_train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct_train / total_train

    # Validation loop
    model.eval()  # Set model to evaluation mode
    val_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            val_loss += criterion(outputs, labels).item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()


    avg_val_loss = val_loss / len(val_loader)
    val_acc = 100 * correct / total
    current_lr = scheduler.get_last_lr()[0]
    print(f'Epoch [{epoch+1}/{num_epochs}], Training Loss: {avg_train_loss:.4f}, Training Accuracy: {train_acc:.4f}, Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_acc:.4f},Learning Rate: {current_lr:.6f}')
   
    # Save the model if validation accuracy improves
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        timestamp = datetime.now().strftime('%Y%m%d-%H%M%S')
        torch.save(model.state_dict(), f'shufflenetv2_256_Run2_Best_Model_epoch{epoch+1}_valacc{val_acc:.2f}_{timestamp}.pth')
        print(f"shufflenetv2_256_Run2 Best model saved at epoch {epoch+1} with validation accuracy: {best_val_acc:.4f}%")

print("Training complete.")
# Out:
# Epoch [1/75], Training Loss: 1.9380, Training Accuracy: 16.3412, Validation Loss: 1.9358, Validation Accuracy: 32.9856,Learning Rate: 0.000045
# shufflenetv2_256_Run2 Best model saved at epoch 1 with validation accuracy: 32.9856%
# Epoch [2/75], Training Loss: 1.9165, Training Accuracy: 36.1700, Validation Loss: 1.9165, Validation Accuracy: 41.5329,Learning Rate: 0.000059
# shufflenetv2_256_Run2 Best model saved at epoch 2 with validation accuracy: 41.5329%
# Epoch [3/75], Training Loss: 1.8443, Training Accuracy: 43.1242, Validation Loss: 1.8589, Validation Accuracy: 37.1589,Learning Rate: 0.000082
# Epoch [4/75], Training Loss: 1.6056, Training Accuracy: 39.2816, Validation Loss: 1.7611, Validation Accuracy: 41.6934,Learning Rate: 0.000113
# shufflenetv2_256_Run2 Best model saved at epoch 4 with validation accuracy: 41.6934%
# Epoch [5/75], Training Loss: 1.3797, Training Accuracy: 41.7667, Validation Loss: 1.6646, Validation Accuracy: 42.9374,Learning Rate: 0.000153
# shufflenetv2_256_Run2 Best model saved at epoch 5 with validation accuracy: 42.9374%
# Epoch [6/75], Training Loss: 1.1773, Training Accuracy: 46.8623, Validation Loss: 1.6016, Validation Accuracy: 49.8395,Learning Rate: 0.000199
# shufflenetv2_256_Run2 Best model saved at epoch 6 with validation accuracy: 49.8395%
# Epoch [7/75], Training Loss: 1.0024, Training Accuracy: 55.4767, Validation Loss: 1.4649, Validation Accuracy: 57.1830,Learning Rate: 0.000252
# shufflenetv2_256_Run2 Best model saved at epoch 7 with validation accuracy: 57.1830%
# Epoch [8/75], Training Loss: 0.8930, Training Accuracy: 60.1545, Validation Loss: 1.3055, Validation Accuracy: 61.4366,Learning Rate: 0.000310
# shufflenetv2_256_Run2 Best model saved at epoch 8 with validation accuracy: 61.4366%
# Epoch [9/75], Training Loss: 0.7615, Training Accuracy: 64.5714, Validation Loss: 1.0349, Validation Accuracy: 67.7769,Learning Rate: 0.000372
# shufflenetv2_256_Run2 Best model saved at epoch 9 with validation accuracy: 67.7769%
# Epoch [10/75], Training Loss: 0.6396, Training Accuracy: 70.3247, Validation Loss: 0.8285, Validation Accuracy: 71.7897,Learning Rate: 0.000437
# shufflenetv2_256_Run2 Best model saved at epoch 10 with validation accuracy: 71.7897%
# Epoch [11/75], Training Loss: 0.5474, Training Accuracy: 72.7890, Validation Loss: 0.6678, Validation Accuracy: 75.6822,Learning Rate: 0.000504
# shufflenetv2_256_Run2 Best model saved at epoch 11 with validation accuracy: 75.6822%
# Epoch [12/75], Training Loss: 0.5214, Training Accuracy: 74.5849, Validation Loss: 0.5849, Validation Accuracy: 78.5313,Learning Rate: 0.000571
# shufflenetv2_256_Run2 Best model saved at epoch 12 with validation accuracy: 78.5313%
# Epoch [13/75], Training Loss: 0.4704, Training Accuracy: 76.6942, Validation Loss: 0.5619, Validation Accuracy: 73.8764,Learning Rate: 0.000637
# Epoch [14/75], Training Loss: 0.4510, Training Accuracy: 77.0074, Validation Loss: 0.6286, Validation Accuracy: 72.7929,Learning Rate: 0.000701
# Epoch [15/75], Training Loss: 0.4268, Training Accuracy: 78.3648, Validation Loss: 0.6366, Validation Accuracy: 71.1477,Learning Rate: 0.000761
# Epoch [16/75], Training Loss: 0.4012, Training Accuracy: 78.3753, Validation Loss: 0.8813, Validation Accuracy: 68.6196,Learning Rate: 0.000817
# Epoch [17/75], Training Loss: 0.3962, Training Accuracy: 79.5447, Validation Loss: 0.5392, Validation Accuracy: 77.2472,Learning Rate: 0.000866
# Epoch [18/75], Training Loss: 0.3797, Training Accuracy: 80.0042, Validation Loss: 0.7562, Validation Accuracy: 71.7496,Learning Rate: 0.000909
# Epoch [19/75], Training Loss: 0.3476, Training Accuracy: 80.7351, Validation Loss: 0.6366, Validation Accuracy: 75.6019,Learning Rate: 0.000945
# Epoch [20/75], Training Loss: 0.3538, Training Accuracy: 81.7166, Validation Loss: 0.4114, Validation Accuracy: 83.5474,Learning Rate: 0.000972
# shufflenetv2_256_Run2 Best model saved at epoch 20 with validation accuracy: 83.5474%
# Epoch [21/75], Training Loss: 0.3396, Training Accuracy: 81.6957, Validation Loss: 0.4142, Validation Accuracy: 84.1091,Learning Rate: 0.000990
# shufflenetv2_256_Run2 Best model saved at epoch 21 with validation accuracy: 84.1091%
# Epoch [22/75], Training Loss: 0.3109, Training Accuracy: 83.1889, Validation Loss: 0.4390, Validation Accuracy: 83.3066,Learning Rate: 0.000999
# Epoch [23/75], Training Loss: 0.2951, Training Accuracy: 83.2620, Validation Loss: 0.4076, Validation Accuracy: 84.0690,Learning Rate: 0.001000
# Epoch [24/75], Training Loss: 0.2704, Training Accuracy: 83.7945, Validation Loss: 0.3661, Validation Accuracy: 85.8347,Learning Rate: 0.000998
# shufflenetv2_256_Run2 Best model saved at epoch 24 with validation accuracy: 85.8347%
# Epoch [25/75], Training Loss: 0.2586, Training Accuracy: 84.8909, Validation Loss: 0.3361, Validation Accuracy: 86.3563,Learning Rate: 0.000994
# shufflenetv2_256_Run2 Best model saved at epoch 25 with validation accuracy: 86.3563%
# Epoch [26/75], Training Loss: 0.2337, Training Accuracy: 85.6636, Validation Loss: 0.3711, Validation Accuracy: 84.5506,Learning Rate: 0.000989
# Epoch [27/75], Training Loss: 0.2241, Training Accuracy: 85.7889, Validation Loss: 0.3259, Validation Accuracy: 87.4398,Learning Rate: 0.000982
# shufflenetv2_256_Run2 Best model saved at epoch 27 with validation accuracy: 87.4398%
# Epoch [28/75], Training Loss: 0.2205, Training Accuracy: 86.3736, Validation Loss: 0.3978, Validation Accuracy: 82.3836,Learning Rate: 0.000973
# Epoch [29/75], Training Loss: 0.1818, Training Accuracy: 87.1463, Validation Loss: 0.3172, Validation Accuracy: 87.1589,Learning Rate: 0.000962
# Epoch [30/75], Training Loss: 0.1736, Training Accuracy: 88.5037, Validation Loss: 0.3656, Validation Accuracy: 86.9181,Learning Rate: 0.000950
# Epoch [31/75], Training Loss: 0.1822, Training Accuracy: 88.3471, Validation Loss: 0.4469, Validation Accuracy: 82.4238,Learning Rate: 0.000936
# Epoch [32/75], Training Loss: 0.1477, Training Accuracy: 89.2555, Validation Loss: 0.2671, Validation Accuracy: 89.6067,Learning Rate: 0.000921
# shufflenetv2_256_Run2 Best model saved at epoch 32 with validation accuracy: 89.6067%
# Epoch [33/75], Training Loss: 0.1589, Training Accuracy: 89.6627, Validation Loss: 0.3758, Validation Accuracy: 85.0321,Learning Rate: 0.000904
# Epoch [34/75], Training Loss: 0.1516, Training Accuracy: 89.6419, Validation Loss: 0.4277, Validation Accuracy: 82.9053,Learning Rate: 0.000886
# Epoch [35/75], Training Loss: 0.1478, Training Accuracy: 89.8611, Validation Loss: 0.3004, Validation Accuracy: 87.3596,Learning Rate: 0.000866
# Epoch [36/75], Training Loss: 0.1272, Training Accuracy: 90.8218, Validation Loss: 0.2476, Validation Accuracy: 90.8507,Learning Rate: 0.000845
# shufflenetv2_256_Run2 Best model saved at epoch 36 with validation accuracy: 90.8507%
# Epoch [37/75], Training Loss: 0.1337, Training Accuracy: 91.7406, Validation Loss: 0.3946, Validation Accuracy: 84.5104,Learning Rate: 0.000823
# Epoch [38/75], Training Loss: 0.1150, Training Accuracy: 91.7928, Validation Loss: 0.2594, Validation Accuracy: 90.0482,Learning Rate: 0.000799
# Epoch [39/75], Training Loss: 0.1087, Training Accuracy: 91.9912, Validation Loss: 0.1607, Validation Accuracy: 93.9807,Learning Rate: 0.000775
# shufflenetv2_256_Run2 Best model saved at epoch 39 with validation accuracy: 93.9807%
# Epoch [40/75], Training Loss: 0.1072, Training Accuracy: 92.8683, Validation Loss: 0.2295, Validation Accuracy: 92.3355,Learning Rate: 0.000749
# Epoch [41/75], Training Loss: 0.0870, Training Accuracy: 93.6201, Validation Loss: 0.2170, Validation Accuracy: 92.2552,Learning Rate: 0.000723
# Epoch [42/75], Training Loss: 0.0778, Training Accuracy: 93.9960, Validation Loss: 0.2102, Validation Accuracy: 91.3323,Learning Rate: 0.000696
# Epoch [43/75], Training Loss: 0.0748, Training Accuracy: 93.7872, Validation Loss: 0.1541, Validation Accuracy: 94.3820,Learning Rate: 0.000668
# shufflenetv2_256_Run2 Best model saved at epoch 43 with validation accuracy: 94.3820%
# Epoch [44/75], Training Loss: 0.0654, Training Accuracy: 94.7792, Validation Loss: 0.1643, Validation Accuracy: 94.1814,Learning Rate: 0.000639
# Epoch [45/75], Training Loss: 0.0642, Training Accuracy: 94.8523, Validation Loss: 0.1941, Validation Accuracy: 93.4992,Learning Rate: 0.000610
# Epoch [46/75], Training Loss: 0.0580, Training Accuracy: 95.6458, Validation Loss: 0.1901, Validation Accuracy: 93.2584,Learning Rate: 0.000581
# Epoch [47/75], Training Loss: 0.0506, Training Accuracy: 95.8024, Validation Loss: 0.1631, Validation Accuracy: 94.5024,Learning Rate: 0.000551
# shufflenetv2_256_Run2 Best model saved at epoch 47 with validation accuracy: 94.5024%
# Epoch [48/75], Training Loss: 0.0474, Training Accuracy: 95.9382, Validation Loss: 0.1494, Validation Accuracy: 95.3852,Learning Rate: 0.000522
# shufflenetv2_256_Run2 Best model saved at epoch 48 with validation accuracy: 95.3852%
# Epoch [49/75], Training Loss: 0.0431, Training Accuracy: 96.3872, Validation Loss: 0.1193, Validation Accuracy: 95.7464,Learning Rate: 0.000492
# shufflenetv2_256_Run2 Best model saved at epoch 49 with validation accuracy: 95.7464%
# Epoch [50/75], Training Loss: 0.0460, Training Accuracy: 96.9928, Validation Loss: 0.1306, Validation Accuracy: 95.5457,Learning Rate: 0.000462
# Epoch [51/75], Training Loss: 0.0341, Training Accuracy: 97.2330, Validation Loss: 0.1261, Validation Accuracy: 95.5859,Learning Rate: 0.000432
# Epoch [52/75], Training Loss: 0.0330, Training Accuracy: 97.3896, Validation Loss: 0.1183, Validation Accuracy: 95.9470,Learning Rate: 0.000403
# shufflenetv2_256_Run2 Best model saved at epoch 52 with validation accuracy: 95.9470%
# Epoch [53/75], Training Loss: 0.0308, Training Accuracy: 97.5775, Validation Loss: 0.1060, Validation Accuracy: 96.2279,Learning Rate: 0.000373
# shufflenetv2_256_Run2 Best model saved at epoch 53 with validation accuracy: 96.2279%
# Epoch [54/75], Training Loss: 0.0248, Training Accuracy: 98.0370, Validation Loss: 0.0987, Validation Accuracy: 96.5490,Learning Rate: 0.000345
# shufflenetv2_256_Run2 Best model saved at epoch 54 with validation accuracy: 96.5490%
# Epoch [55/75], Training Loss: 0.0229, Training Accuracy: 97.9012, Validation Loss: 0.0879, Validation Accuracy: 97.3114,Learning Rate: 0.000317
# shufflenetv2_256_Run2 Best model saved at epoch 55 with validation accuracy: 97.3114%
# Epoch [56/75], Training Loss: 0.0196, Training Accuracy: 98.3607, Validation Loss: 0.0964, Validation Accuracy: 96.8299,Learning Rate: 0.000289
# Epoch [57/75], Training Loss: 0.0224, Training Accuracy: 98.2876, Validation Loss: 0.1190, Validation Accuracy: 96.2681,Learning Rate: 0.000262
# Epoch [58/75], Training Loss: 0.0199, Training Accuracy: 98.4546, Validation Loss: 0.0871, Validation Accuracy: 97.3114,Learning Rate: 0.000236
# Epoch [59/75], Training Loss: 0.0169, Training Accuracy: 98.5904, Validation Loss: 0.0923, Validation Accuracy: 96.9904,Learning Rate: 0.000212
# Epoch [60/75], Training Loss: 0.0174, Training Accuracy: 98.5486, Validation Loss: 0.0973, Validation Accuracy: 97.1910,Learning Rate: 0.000188
# Epoch [61/75], Training Loss: 0.0135, Training Accuracy: 98.9141, Validation Loss: 0.0770, Validation Accuracy: 97.5923,Learning Rate: 0.000165
# shufflenetv2_256_Run2 Best model saved at epoch 61 with validation accuracy: 97.5923%
# Epoch [62/75], Training Loss: 0.0127, Training Accuracy: 98.7470, Validation Loss: 0.0787, Validation Accuracy: 97.3515,Learning Rate: 0.000143
# Epoch [63/75], Training Loss: 0.0164, Training Accuracy: 99.0707, Validation Loss: 0.0770, Validation Accuracy: 97.6324,Learning Rate: 0.000123
# shufflenetv2_256_Run2 Best model saved at epoch 63 with validation accuracy: 97.6324%
# Epoch [64/75], Training Loss: 0.0095, Training Accuracy: 99.1125, Validation Loss: 0.0706, Validation Accuracy: 98.3547,Learning Rate: 0.000104
# shufflenetv2_256_Run2 Best model saved at epoch 64 with validation accuracy: 98.3547%
# Epoch [65/75], Training Loss: 0.0126, Training Accuracy: 99.1855, Validation Loss: 0.0766, Validation Accuracy: 97.7127,Learning Rate: 0.000086
# Epoch [66/75], Training Loss: 0.0105, Training Accuracy: 99.1229, Validation Loss: 0.0880, Validation Accuracy: 97.7528,Learning Rate: 0.000070
# Epoch [67/75], Training Loss: 0.0080, Training Accuracy: 99.2378, Validation Loss: 0.0827, Validation Accuracy: 97.8331,Learning Rate: 0.000056
# Epoch [68/75], Training Loss: 0.0102, Training Accuracy: 99.2900, Validation Loss: 0.0738, Validation Accuracy: 97.9936,Learning Rate: 0.000043
# Epoch [69/75], Training Loss: 0.0090, Training Accuracy: 99.1125, Validation Loss: 0.0709, Validation Accuracy: 97.9936,Learning Rate: 0.000032
# Epoch [70/75], Training Loss: 0.0079, Training Accuracy: 99.2795, Validation Loss: 0.0806, Validation Accuracy: 97.9133,Learning Rate: 0.000022
# Epoch [71/75], Training Loss: 0.0080, Training Accuracy: 99.3108, Validation Loss: 0.0736, Validation Accuracy: 97.9535,Learning Rate: 0.000014
# Epoch [72/75], Training Loss: 0.0081, Training Accuracy: 99.2378, Validation Loss: 0.0689, Validation Accuracy: 98.1541,Learning Rate: 0.000008
# Epoch [73/75], Training Loss: 0.0082, Training Accuracy: 99.4048, Validation Loss: 0.0714, Validation Accuracy: 98.2745,Learning Rate: 0.000003
# Epoch [74/75], Training Loss: 0.0087, Training Accuracy: 99.3004, Validation Loss: 0.0784, Validation Accuracy: 98.0337,Learning Rate: 0.000001
# Epoch [75/75], Training Loss: 0.0081, Training Accuracy: 99.1960, Validation Loss: 0.0751, Validation Accuracy: 97.7528,Learning Rate: 0.000000
# Training complete.

# %%
torch.save(model.state_dict(),'shufflenetv2_256_Run2_Final_model_3.pth')

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Initialize test variables
model.eval()  # Set the model to evaluation mode
test_loss = 0.0
correct = 0
total = 0

# Initialize placeholders for predictions and true labels
all_preds = []
all_labels = []

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)

        test_loss += loss.item()

        # Collect predictions and true labels for the confusion matrix
        _, predicted = torch.max(outputs.data, 1)
        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

        # Calculate accuracy
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

# Calculate average loss and accuracy
avg_test_loss = test_loss / len(test_loader)
test_accuracy = 100 * correct / total

print(f"Test Loss: {avg_test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")

# Generate the confusion matrix
conf_matrix = confusion_matrix(all_labels, all_preds)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)
disp.plot(cmap=plt.cm.PuBu, values_format='d')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Test Loss: 0.0673, Test Accuracy: 97.43%
